# %%
import os
import numpy as np
import imagecodecs
from skimage.io import imsave, imread

tr_path = './tr/'
ts_path = './ts/'
pred_path = './preds/'

image_rows = 420
image_cols = 580

# %%
def create_train_data():
    tr_data_path = os.path.join(tr_path)
    images = os.listdir(tr_data_path)
    total = int(len(images) / 2)

    imgs = np.ndarray((total, image_rows, image_cols), dtype=np.uint8)
    imgs_mask = np.ndarray((total, image_rows, image_cols), dtype=np.uint8)

    i = 0
    print('------------------------------')
    print('Fetching training images...')
    print('------------------------------')
    for image_name in images:
        if 'mask' in image_name:
            continue
        image_mask_name = image_name.split('.')[0] + '_mask.tif'
        img = imread(os.path.join(tr_data_path, image_name), as_gray=True)
        img_mask = imread(os.path.join(tr_data_path, image_mask_name), as_gray=True)

        img = np.array([img])
        img_mask = np.array([img_mask])

        imgs[i] = img
        imgs_mask[i] = img_mask

        print("Converted ", (i+1), "/", total, " images")
        i += 1
    print('Loading done.')

    np.save('imgs_train.npy', imgs)
    np.save('imgs_mask_train.npy', imgs_mask)
    print('Saving to .npy files done.')

# %%
def create_test_data():
    ts_data_path = os.path.join(ts_path)
    images = os.listdir(ts_data_path)
    total = len(images)

    imgs = np.ndarray((total, image_rows, image_cols), dtype=np.uint8)
    imgs_id = np.ndarray((total, ), dtype=np.int32)

    i = 0
    print('------------------------------')
    print('Creating test images...')
    print('------------------------------')
    for image_name in images:
        if 'mask' in image_name:
            continue
        img_id = int(image_name.split('.')[0])
        img = imread(os.path.join(ts_data_path, image_name), as_gray=True)

        img = np.array([img])

        imgs[i] = img
        imgs_id[i] = img_id

        print("Converted ", (i+1), "/", total, " images")
        i += 1
    print('Loading done.')

    np.save('imgs_test.npy', imgs)
    np.save('imgs_id_test.npy', imgs_id)
    print('Saving to .npy files done.')

# %%
def load_train_data():
    imgs_train = np.load('imgs_train.npy')
    imgs_mask_train = np.load('imgs_mask_train.npy')
    return imgs_train, imgs_mask_train

# %%
def load_test_data():
        imgs_test = np.load('imgs_test.npy')
        imgs_id = np.load('imgs_id_test.npy')
        return imgs_test, imgs_id

# %%
create_train_data()
create_test_data()
# Out:
# ------------------------------
# Fetching training images...
# ------------------------------
# Converted  1 / 240  images
# Converted  2 / 240  images
# Converted  3 / 240  images
# Converted  4 / 240  images
# Converted  5 / 240  images
# Converted  6 / 240  images
# Converted  7 / 240  images
# Converted  8 / 240  images
# Converted  9 / 240  images
# Converted  10 / 240  images
# Converted  11 / 240  images
# Converted  12 / 240  images
# Converted  13 / 240  images
# Converted  14 / 240  images
# Converted  15 / 240  images
# Converted  16 / 240  images
# Converted  17 / 240  images
# Converted  18 / 240  images
# Converted  19 / 240  images
# Converted  20 / 240  images
# Converted  21 / 240  images
# Converted  22 / 240  images
# Converted  23 / 240  images
# Converted  24 / 240  images
# Converted  25 / 240  images
# Converted  26 / 240  images
# Converted  27 / 240  images
# Converted  28 / 240  images
# Converted  29 / 240  images
# Converted  30 / 240  images
# Converted  31 / 240  images
# Converted  32 / 240  images
# Converted  33 / 240  images
# Converted  34 / 240  images
# Converted  35 / 240  images
# Converted  36 / 240  images
# Converted  37 / 240  images
# Converted  38 / 240  images
# Converted  39 / 240  images
# Converted  40 / 240  images
# Converted  41 / 240  images
# Converted  42 / 240  images
# Converted  43 / 240  images
# Converted  44 / 240  images
# Converted  45 / 240  images
# Converted  46 / 240  images
# Converted  47 / 240  images
# Converted  48 / 240  images
# Converted  49 / 240  images
# Converted  50 / 240  images
# Converted  51 / 240  images
# Converted  52 / 240  images
# Converted  53 / 240  images
# Converted  54 / 240  images
# Converted  55 / 240  images
# Converted  56 / 240  images
# Converted  57 / 240  images
# Converted  58 / 240  images
# Converted  59 / 240  images
# Converted  60 / 240  images
# Converted  61 / 240  images
# Converted  62 / 240  images
# Converted  63 / 240  images
# Converted  64 / 240  images
# Converted  65 / 240  images
# Converted  66 / 240  images
# Converted  67 / 240  images
# Converted  68 / 240  images
# Converted  69 / 240  images
# Converted  70 / 240  images
# Converted  71 / 240  images
# Converted  72 / 240  images
# Converted  73 / 240  images
# Converted  74 / 240  images
# Converted  75 / 240  images
# Converted  76 / 240  images
# Converted  77 / 240  images
# Converted  78 / 240  images
# Converted  79 / 240  images
# Converted  80 / 240  images
# Converted  81 / 240  images
# Converted  82 / 240  images
# Converted  83 / 240  images
# Converted  84 / 240  images
# Converted  85 / 240  images
# Converted  86 / 240  images
# Converted  87 / 240  images
# Converted  88 / 240  images
# Converted  89 / 240  images
# Converted  90 / 240  images
# Converted  91 / 240  images
# Converted  92 / 240  images
# Converted  93 / 240  images
# Converted  94 / 240  images
# Converted  95 / 240  images
# Converted  96 / 240  images
# Converted  97 / 240  images
# Converted  98 / 240  images
# Converted  99 / 240  images
# Converted  100 / 240  images
# Converted  101 / 240  images
# Converted  102 / 240  images
# Converted  103 / 240  images
# Converted  104 / 240  images
# Converted  105 / 240  images
# Converted  106 / 240  images
# Converted  107 / 240  images
# Converted  108 / 240  images
# Converted  109 / 240  images
# Converted  110 / 240  images
# Converted  111 / 240  images
# Converted  112 / 240  images
# Converted  113 / 240  images
# Converted  114 / 240  images
# Converted  115 / 240  images
# Converted  116 / 240  images
# Converted  117 / 240  images
# Converted  118 / 240  images
# Converted  119 / 240  images
# Converted  120 / 240  images
# Converted  121 / 240  images
# Converted  122 / 240  images
# Converted  123 / 240  images
# Converted  124 / 240  images
# Converted  125 / 240  images
# Converted  126 / 240  images
# Converted  127 / 240  images
# Converted  128 / 240  images
# Converted  129 / 240  images
# Converted  130 / 240  images
# Converted  131 / 240  images
# Converted  132 / 240  images
# Converted  133 / 240  images
# Converted  134 / 240  images
# Converted  135 / 240  images
# Converted  136 / 240  images
# Converted  137 / 240  images
# Converted  138 / 240  images
# Converted  139 / 240  images
# Converted  140 / 240  images
# Converted  141 / 240  images
# Converted  142 / 240  images
# Converted  143 / 240  images
# Converted  144 / 240  images
# Converted  145 / 240  images
# Converted  146 / 240  images
# Converted  147 / 240  images
# Converted  148 / 240  images
# Converted  149 / 240  images
# Converted  150 / 240  images
# Converted  151 / 240  images
# Converted  152 / 240  images
# Converted  153 / 240  images
# Converted  154 / 240  images
# Converted  155 / 240  images
# Converted  156 / 240  images
# Converted  157 / 240  images
# Converted  158 / 240  images
# Converted  159 / 240  images
# Converted  160 / 240  images
# Converted  161 / 240  images
# Converted  162 / 240  images
# Converted  163 / 240  images
# Converted  164 / 240  images
# Converted  165 / 240  images
# Converted  166 / 240  images
# Converted  167 / 240  images
# Converted  168 / 240  images
# Converted  169 / 240  images
# Converted  170 / 240  images
# Converted  171 / 240  images
# Converted  172 / 240  images
# Converted  173 / 240  images
# Converted  174 / 240  images
# Converted  175 / 240  images
# Converted  176 / 240  images
# Converted  177 / 240  images
# Converted  178 / 240  images
# Converted  179 / 240  images
# Converted  180 / 240  images
# Converted  181 / 240  images
# Converted  182 / 240  images
# Converted  183 / 240  images
# Converted  184 / 240  images
# Converted  185 / 240  images
# Converted  186 / 240  images
# Converted  187 / 240  images
# Converted  188 / 240  images
# Converted  189 / 240  images
# Converted  190 / 240  images
# Converted  191 / 240  images
# Converted  192 / 240  images
# Converted  193 / 240  images
# Converted  194 / 240  images
# Converted  195 / 240  images
# Converted  196 / 240  images
# Converted  197 / 240  images
# Converted  198 / 240  images
# Converted  199 / 240  images
# Converted  200 / 240  images
# Converted  201 / 240  images
# Converted  202 / 240  images
# Converted  203 / 240  images
# Converted  204 / 240  images
# Converted  205 / 240  images
# Converted  206 / 240  images
# Converted  207 / 240  images
# Converted  208 / 240  images
# Converted  209 / 240  images
# Converted  210 / 240  images
# Converted  211 / 240  images
# Converted  212 / 240  images
# Converted  213 / 240  images
# Converted  214 / 240  images
# Converted  215 / 240  images
# Converted  216 / 240  images
# Converted  217 / 240  images
# Converted  218 / 240  images
# Converted  219 / 240  images
# Converted  220 / 240  images
# Converted  221 / 240  images
# Converted  222 / 240  images
# Converted  223 / 240  images
# Converted  224 / 240  images
# Converted  225 / 240  images
# Converted  226 / 240  images
# Converted  227 / 240  images
# Converted  228 / 240  images
# Converted  229 / 240  images
# Converted  230 / 240  images
# Converted  231 / 240  images
# Converted  232 / 240  images
# Converted  233 / 240  images
# Converted  234 / 240  images
# Converted  235 / 240  images
# Converted  236 / 240  images
# Converted  237 / 240  images
# Converted  238 / 240  images
# Converted  239 / 240  images
# Converted  240 / 240  images
# Loading done.
# Saving to .npy files done.
# ------------------------------
# Creating test images...
# ------------------------------
# Converted  1 / 238  images
# Converted  2 / 238  images
# Converted  3 / 238  images
# Converted  4 / 238  images
# Converted  5 / 238  images
# Converted  6 / 238  images
# Converted  7 / 238  images
# Converted  8 / 238  images
# Converted  9 / 238  images
# Converted  10 / 238  images
# Converted  11 / 238  images
# Converted  12 / 238  images
# Converted  13 / 238  images
# Converted  14 / 238  images
# Converted  15 / 238  images
# Converted  16 / 238  images
# Converted  17 / 238  images
# Converted  18 / 238  images
# Converted  19 / 238  images
# Converted  20 / 238  images
# Converted  21 / 238  images
# Converted  22 / 238  images
# Converted  23 / 238  images
# Converted  24 / 238  images
# Converted  25 / 238  images
# Converted  26 / 238  images
# Converted  27 / 238  images
# Converted  28 / 238  images
# Converted  29 / 238  images
# Converted  30 / 238  images
# Converted  31 / 238  images
# Converted  32 / 238  images
# Converted  33 / 238  images
# Converted  34 / 238  images
# Converted  35 / 238  images
# Converted  36 / 238  images
# Converted  37 / 238  images
# Converted  38 / 238  images
# Converted  39 / 238  images
# Converted  40 / 238  images
# Converted  41 / 238  images
# Converted  42 / 238  images
# Converted  43 / 238  images
# Converted  44 / 238  images
# Converted  45 / 238  images
# Converted  46 / 238  images
# Converted  47 / 238  images
# Converted  48 / 238  images
# Converted  49 / 238  images
# Converted  50 / 238  images
# Converted  51 / 238  images
# Converted  52 / 238  images
# Converted  53 / 238  images
# Converted  54 / 238  images
# Converted  55 / 238  images
# Converted  56 / 238  images
# Converted  57 / 238  images
# Converted  58 / 238  images
# Converted  59 / 238  images
# Converted  60 / 238  images
# Converted  61 / 238  images
# Converted  62 / 238  images
# Converted  63 / 238  images
# Converted  64 / 238  images
# Converted  65 / 238  images
# Converted  66 / 238  images
# Converted  67 / 238  images
# Converted  68 / 238  images
# Converted  69 / 238  images
# Converted  70 / 238  images
# Converted  71 / 238  images
# Converted  72 / 238  images
# Converted  73 / 238  images
# Converted  74 / 238  images
# Converted  75 / 238  images
# Converted  76 / 238  images
# Converted  77 / 238  images
# Converted  78 / 238  images
# Converted  79 / 238  images
# Converted  80 / 238  images
# Converted  81 / 238  images
# Converted  82 / 238  images
# Converted  83 / 238  images
# Converted  84 / 238  images
# Converted  85 / 238  images
# Converted  86 / 238  images
# Converted  87 / 238  images
# Converted  88 / 238  images
# Converted  89 / 238  images
# Converted  90 / 238  images
# Converted  91 / 238  images
# Converted  92 / 238  images
# Converted  93 / 238  images
# Converted  94 / 238  images
# Converted  95 / 238  images
# Converted  96 / 238  images
# Converted  97 / 238  images
# Converted  98 / 238  images
# Converted  99 / 238  images
# Converted  100 / 238  images
# Converted  101 / 238  images
# Converted  102 / 238  images
# Converted  103 / 238  images
# Converted  104 / 238  images
# Converted  105 / 238  images
# Converted  106 / 238  images
# Converted  107 / 238  images
# Converted  108 / 238  images
# Converted  109 / 238  images
# Converted  110 / 238  images
# Converted  111 / 238  images
# Converted  112 / 238  images
# Converted  113 / 238  images
# Converted  114 / 238  images
# Converted  115 / 238  images
# Converted  116 / 238  images
# Converted  117 / 238  images
# Converted  118 / 238  images
# Converted  119 / 238  images
# Loading done.
# Saving to .npy files done.

# %%
from __future__ import print_function

import os
from skimage.transform import resize
from skimage.io import imsave
from keras.models import Model
from keras.layers import Input, concatenate, Conv2D, MaxPooling2D, Conv2DTranspose
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from keras import backend as K




def dice_coef(y_true, y_pred):
    y_true_flattened = K.flatten(y_true)
    y_pred_flattened = K.flatten(y_pred)
    intersection = K.sum(y_true_flattened * y_pred_flattened)
    return (2. * intersection + smooth) / (K.sum(y_true_flattened) + K.sum(y_pred_flattened) + smooth)


def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# %%
K.set_image_data_format('channels_last')  # TF dimension ordering in this code

img_rows = 96
img_cols = 96
smooth = 1.


def unet():
    inputs = Input((img_rows, img_cols, 1))
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

    model = Model(inputs=[inputs], outputs=[conv10])
    model.compile(optimizer=Adam(lr=1e-5), loss=dice_coef_loss, metrics=[dice_coef])
    model.summary()
    return model

# %%
def preprocess(imgs):
    imgs_p = np.ndarray((imgs.shape[0], img_rows, img_cols), dtype=np.uint8)
    for i in range(imgs.shape[0]):
        imgs_p[i] = resize(imgs[i], (img_cols, img_rows), preserve_range=True)

    imgs_p = imgs_p[..., np.newaxis]
    return imgs_p

# %%
def train_and_predict():
    print('------------------------------')
    print('Loading and preprocessing training data...')
    print('------------------------------')
    imgs_train, imgs_mask_train = load_train_data()

    imgs_train = preprocess(imgs_train)
    imgs_mask_train = preprocess(imgs_mask_train)

    imgs_train = imgs_train.astype('float32')
    mean = np.mean(imgs_train)  
    std = np.std(imgs_train)  

    imgs_train -= mean
    imgs_train /= std

    imgs_mask_train = imgs_mask_train.astype('float32')
    imgs_mask_train /= 255.  # scale masks to [0, 1]

    print('------------------------------')
    print('Creating and compiling model...')
    print('------------------------------')
    model = unet()
    model_checkpoint = ModelCheckpoint('weights.h5', monitor='val_loss', save_best_only=True)

    print('------------------------------')
    print('Fitting model...')
    print('------------------------------')
    model.fit(imgs_train, imgs_mask_train, batch_size=16, epochs=50, verbose=1, shuffle=True,
              callbacks=[model_checkpoint])

    print('------------------------------')
    print('Loading and preprocessing test data...')
    print('------------------------------')
    imgs_test, imgs_id_test = load_test_data()
    imgs_test = preprocess(imgs_test)

    imgs_test = imgs_test.astype('float32')
    imgs_test -= mean
    imgs_test /= std

    print('------------------------------')
    print('Loading saved weights...')
    print('------------------------------')
    model.save_weights('weights.h5')

    print('------------------------------')
    print('Predicting masks on test data...')
    print('------------------------------')
    imgs_mask_test = model.predict(imgs_test, verbose=1)
    np.save('imgs_mask_test.npy', imgs_mask_test)

    print('------------------------------')
    print('Saving predicted masks to files...')
    print('------------------------------')

    if not os.path.exists(pred_path):
        os.mkdir(pred_path)
    for image, image_id in zip(imgs_mask_test, imgs_id_test):
        image = (image[:, :, 0] * 255.).astype(np.uint8)
        imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)

# %%
train_and_predict()
# Out:
# ------------------------------
# Loading and preprocessing training data...
# ------------------------------
# ------------------------------
# Creating and compiling model...
# ------------------------------
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 96, 96, 1)]  0           []
#
#  conv2d (Conv2D)                (None, 96, 96, 32)   320         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 96, 96, 32)   9248        ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 48, 48, 32)   0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 48, 48, 64)   18496       ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 48, 48, 64)   36928       ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 24, 24, 64)  0           ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 24, 24, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 24, 24, 128)  147584      ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 12, 12, 128)  0          ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 12, 12, 256)  295168      ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 12, 12, 256)  590080      ['conv2d_6[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 6, 6, 256)   0           ['conv2d_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 6, 6, 512)    1180160     ['max_pooling2d_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 6, 6, 512)    2359808     ['conv2d_8[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 12, 12, 256)  524544     ['conv2d_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 12, 12, 512)  0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 12, 12, 256)  1179904     ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 12, 12, 256)  590080      ['conv2d_10[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 24, 24, 128)  131200     ['conv2d_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 24, 24, 256)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 24, 24, 128)  295040      ['concatenate_1[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 24, 24, 128)  147584      ['conv2d_12[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 48, 48, 64)  32832       ['conv2d_13[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 48, 48, 128)  0           ['conv2d_transpose_2[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 48, 48, 64)   73792       ['concatenate_2[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 48, 48, 64)   36928       ['conv2d_14[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 96, 96, 32)  8224        ['conv2d_15[0][0]']
#  spose)
#
#  concatenate_3 (Concatenate)    (None, 96, 96, 64)   0           ['conv2d_transpose_3[0][0]',
#                                                                   'conv2d_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 96, 96, 32)   18464       ['concatenate_3[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 96, 96, 32)   9248        ['conv2d_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 96, 96, 1)    33          ['conv2d_17[0][0]']
#
# ==================================================================================================
# Total params: 7,759,521
# Trainable params: 7,759,521
# Non-trainable params: 0
# __________________________________________________________________________________________________
# ------------------------------
# Fitting model...
# ------------------------------
# Epoch 1/50
# C:\Users\Harshal\AppData\Roaming\Python\Python311\site-packages\keras\optimizers\legacy\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 15/15 [==============================] - ETA: 0s - loss: -0.0142 - dice_coef: 0.0142WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 20s 1s/step - loss: -0.0142 - dice_coef: 0.0142
# Epoch 2/50
# 15/15 [==============================] - ETA: 0s - loss: -0.0143 - dice_coef: 0.0143WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.0143 - dice_coef: 0.0143
# Epoch 3/50
# 15/15 [==============================] - ETA: 0s - loss: -0.0144 - dice_coef: 0.0144WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.0144 - dice_coef: 0.0144
# Epoch 4/50
# 15/15 [==============================] - ETA: 0s - loss: -0.0145 - dice_coef: 0.0145WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.0145 - dice_coef: 0.0145
# Epoch 5/50
# 15/15 [==============================] - ETA: 0s - loss: -0.0146 - dice_coef: 0.0146WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.0146 - dice_coef: 0.0146
# Epoch 6/50
# 15/15 [==============================] - ETA: 0s - loss: -0.0147 - dice_coef: 0.0147WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.0147 - dice_coef: 0.0147
# Epoch 7/50
# 15/15 [==============================] - ETA: 0s - loss: -0.0149 - dice_coef: 0.0149WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.0149 - dice_coef: 0.0149
# Epoch 8/50
# 15/15 [==============================] - ETA: 0s - loss: -0.0150 - dice_coef: 0.0150WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.0150 - dice_coef: 0.0150
# Epoch 9/50
# 15/15 [==============================] - ETA: 0s - loss: -0.0152 - dice_coef: 0.0152WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.0152 - dice_coef: 0.0152
# Epoch 10/50
# 15/15 [==============================] - ETA: 0s - loss: -0.0155 - dice_coef: 0.0155WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.0155 - dice_coef: 0.0155
# Epoch 11/50
# 15/15 [==============================] - ETA: 0s - loss: -0.0158 - dice_coef: 0.0158WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.0158 - dice_coef: 0.0158
# Epoch 12/50
# 15/15 [==============================] - ETA: 0s - loss: -0.0161 - dice_coef: 0.0161WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.0161 - dice_coef: 0.0161
# Epoch 13/50
# 15/15 [==============================] - ETA: 0s - loss: -0.0166 - dice_coef: 0.0166WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.0166 - dice_coef: 0.0166
# Epoch 14/50
# 15/15 [==============================] - ETA: 0s - loss: -0.0173 - dice_coef: 0.0173WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.0173 - dice_coef: 0.0173
# Epoch 15/50
# 15/15 [==============================] - ETA: 0s - loss: -0.0181 - dice_coef: 0.0181WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.0181 - dice_coef: 0.0181
# Epoch 16/50
# 15/15 [==============================] - ETA: 0s - loss: -0.0195 - dice_coef: 0.0195WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.0195 - dice_coef: 0.0195
# Epoch 17/50
# 15/15 [==============================] - ETA: 0s - loss: -0.0222 - dice_coef: 0.0222WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.0222 - dice_coef: 0.0222
# Epoch 18/50
# 15/15 [==============================] - ETA: 0s - loss: -0.0309 - dice_coef: 0.0309WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.0309 - dice_coef: 0.0309
# Epoch 19/50
# 15/15 [==============================] - ETA: 0s - loss: -0.0689 - dice_coef: 0.0689WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.0689 - dice_coef: 0.0689
# Epoch 20/50
# 15/15 [==============================] - ETA: 0s - loss: -0.1297 - dice_coef: 0.1297WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.1297 - dice_coef: 0.1297
# Epoch 21/50
# 15/15 [==============================] - ETA: 0s - loss: -0.1806 - dice_coef: 0.1806WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.1806 - dice_coef: 0.1806
# Epoch 22/50
# 15/15 [==============================] - ETA: 0s - loss: -0.1020 - dice_coef: 0.1020WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.1020 - dice_coef: 0.1020
# Epoch 23/50
# 15/15 [==============================] - ETA: 0s - loss: -0.2157 - dice_coef: 0.2157WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.2157 - dice_coef: 0.2157
# Epoch 24/50
# 15/15 [==============================] - ETA: 0s - loss: -0.3038 - dice_coef: 0.3038WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.3038 - dice_coef: 0.3038
# Epoch 25/50
# 15/15 [==============================] - ETA: 0s - loss: -0.3541 - dice_coef: 0.3541WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.3541 - dice_coef: 0.3541
# Epoch 26/50
# 15/15 [==============================] - ETA: 0s - loss: -0.3688 - dice_coef: 0.3688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.3688 - dice_coef: 0.3688
# Epoch 27/50
# 15/15 [==============================] - ETA: 0s - loss: -0.3766 - dice_coef: 0.3766WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.3766 - dice_coef: 0.3766
# Epoch 28/50
# 15/15 [==============================] - ETA: 0s - loss: -0.3734 - dice_coef: 0.3734WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.3734 - dice_coef: 0.3734
# Epoch 29/50
# 15/15 [==============================] - ETA: 0s - loss: -0.2328 - dice_coef: 0.2328WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.2328 - dice_coef: 0.2328
# Epoch 30/50
# 15/15 [==============================] - ETA: 0s - loss: -0.0726 - dice_coef: 0.0726WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.0726 - dice_coef: 0.0726
# Epoch 31/50
# 15/15 [==============================] - ETA: 0s - loss: -0.1078 - dice_coef: 0.1078WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.1078 - dice_coef: 0.1078
# Epoch 32/50
# 15/15 [==============================] - ETA: 0s - loss: -0.2695 - dice_coef: 0.2695WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.2695 - dice_coef: 0.2695
# Epoch 33/50
# 15/15 [==============================] - ETA: 0s - loss: -0.3507 - dice_coef: 0.3507WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.3507 - dice_coef: 0.3507
# Epoch 34/50
# 15/15 [==============================] - ETA: 0s - loss: -0.4106 - dice_coef: 0.4106WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.4106 - dice_coef: 0.4106
# Epoch 35/50
# 15/15 [==============================] - ETA: 0s - loss: -0.4063 - dice_coef: 0.4063WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.4063 - dice_coef: 0.4063
# Epoch 36/50
# 15/15 [==============================] - ETA: 0s - loss: -0.4121 - dice_coef: 0.4121WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.4121 - dice_coef: 0.4121
# Epoch 37/50
# 15/15 [==============================] - ETA: 0s - loss: -0.4405 - dice_coef: 0.4405WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.4405 - dice_coef: 0.4405
# Epoch 38/50
# 15/15 [==============================] - ETA: 0s - loss: -0.4143 - dice_coef: 0.4143WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.4143 - dice_coef: 0.4143
# Epoch 39/50
# 15/15 [==============================] - ETA: 0s - loss: -0.4221 - dice_coef: 0.4221WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.4221 - dice_coef: 0.4221
# Epoch 40/50
# 15/15 [==============================] - ETA: 0s - loss: -0.4321 - dice_coef: 0.4321WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.4321 - dice_coef: 0.4321
# Epoch 41/50
# 15/15 [==============================] - ETA: 0s - loss: -0.4717 - dice_coef: 0.4717WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.4717 - dice_coef: 0.4717
# Epoch 42/50
# 15/15 [==============================] - ETA: 0s - loss: -0.4418 - dice_coef: 0.4418WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.4418 - dice_coef: 0.4418
# Epoch 43/50
# 15/15 [==============================] - ETA: 0s - loss: -0.4480 - dice_coef: 0.4480WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.4480 - dice_coef: 0.4480
# Epoch 44/50
# 15/15 [==============================] - ETA: 0s - loss: -0.4620 - dice_coef: 0.4620WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.4620 - dice_coef: 0.4620
# Epoch 45/50
# 15/15 [==============================] - ETA: 0s - loss: -0.4469 - dice_coef: 0.4469WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.4469 - dice_coef: 0.4469
# Epoch 46/50
# 15/15 [==============================] - ETA: 0s - loss: -0.4559 - dice_coef: 0.4559WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.4559 - dice_coef: 0.4559
# Epoch 47/50
# 15/15 [==============================] - ETA: 0s - loss: -0.4327 - dice_coef: 0.4327WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.4327 - dice_coef: 0.4327
# Epoch 48/50
# 15/15 [==============================] - ETA: 0s - loss: -0.4512 - dice_coef: 0.4512WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.4512 - dice_coef: 0.4512
# Epoch 49/50
# 15/15 [==============================] - ETA: 0s - loss: -0.4018 - dice_coef: 0.4018WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.4018 - dice_coef: 0.4018
# Epoch 50/50
# 15/15 [==============================] - ETA: 0s - loss: -0.4100 - dice_coef: 0.4100WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/15 [==============================] - 18s 1s/step - loss: -0.4100 - dice_coef: 0.4100
# ------------------------------
# Loading and preprocessing test data...
# ------------------------------
# ------------------------------
# Loading saved weights...
# ------------------------------
# ------------------------------
# Predicting masks on test data...
# ------------------------------
# 8/8 [==============================] - 3s 346ms/step
# ------------------------------
# Saving predicted masks to files...
# ------------------------------
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/31_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/310_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/3100_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/3101_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/3103_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/3104_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/3105_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/3106_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/3107_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/3109_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/3110_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/3111_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/3112_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/3113_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/3114_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/3115_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/3116_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/3117_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/3118_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/3119_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/312_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/314_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/315_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/316_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/317_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/318_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/32_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/320_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/321_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/322_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/323_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/324_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/325_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/326_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/327_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/328_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/329_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/33_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/330_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/332_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/333_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/334_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/335_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/336_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/337_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/338_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/339_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/34_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/340_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/341_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/342_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/343_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/344_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/345_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/346_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/347_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/348_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/349_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/35_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/350_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/352_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/353_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/354_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/356_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/357_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/358_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/359_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/36_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/360_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/361_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/362_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/363_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/364_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/366_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/367_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/368_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/369_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/370_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/371_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/372_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/373_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/374_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/375_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/376_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/377_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/378_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/379_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/38_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/380_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/381_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/383_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/384_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/385_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/387_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/389_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/39_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/390_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/392_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/393_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/395_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/396_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/397_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/398_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1935764775_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1763714923_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1835606126_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1600481121_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1701667182_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/538970682_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/538976288_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1868767264_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1852404846_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/537552245_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1763713056_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1767860077_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/540876900_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/678719081_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1734438249_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1634623333_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1932420461_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1953066096_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/657336104_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1563450153_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/538970665_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1835606048_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/540876903_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1701997929_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1864918113_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1634741875_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1781426292_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/678324591_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1683977076_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1600222305_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1752457584_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1835606060_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1629498409_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1919377267_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1413314913_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/694515058_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/538970634_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1630433390_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/2036429426_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1835621160_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/170483047_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/538976266_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1735223584_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1567185779_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1763720480_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/537552749_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1601398637_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1767597161_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/540876893_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1600613737_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/168453225_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1852404336_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1126312052_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1702260335_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1684370546_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/539763232_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/824928552_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/572533801_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/539763247_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1635020660_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/572533868_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1634560288_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/577987943_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/543760416_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/824196395_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1769107488_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/656962670_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1684107084_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/543649385_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1701736292_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/170469166_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/779120160_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1702257011_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1835607848_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1952412519_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/779383653_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/662270062_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/170488679_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1932423278_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/677738081_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1735223591_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1684627315_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1936028767_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1886269044_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/539764601_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1936158057_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/694446431_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1769365843_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1948280686_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1848516719_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1713404272_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1936026729_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/1852793888_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/690433637_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/65546_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/5441404_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
# C:\Users\Harshal\AppData\Local\Temp\ipykernel_9996\1950911102.py:61: UserWarning: ./preds/-265222912_pred.png is a low contrast image
#   imsave(os.path.join(pred_path, str(image_id) + '_pred.png'), image)
